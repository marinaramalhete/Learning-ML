# %% [markdown]
# # Centralidade
#
# #### 1 - Carregando bibliotecas e redes

# %%
import networkx as nx
#from networkx.drawing.nx_agraph import write_dot, graphviz_layout
import matplotlib.pyplot as plt
# %matplotlib inline

#Karate-club
K = nx.karate_club_graph()
K = nx.convert_node_labels_to_integers(K, first_label=1)

colors = []
for v in K:
    colors.append(K.degree(v))

nx.draw_kamada_kawai(K, node_color=colors, with_labels=True, cmap=plt.cm.Oranges, node_size=500, font_weight='bold')

plt.show()

#Rede direcionada
DG = nx.DiGraph()
DG.add_edges_from([('D','A'),('D','C'),('D','E'),
                  ('E','A'),('A','B'),('B','C'),
                  ('B','D'),('C','B'),('C','B')])
#DG.add_edges_from([('B','F'),('B','G'),('G','F'),('F','G')])


colors = []
for v in DG:
    colors.append(DG.degree(v));

nx.draw_kamada_kawai(DG, node_color=colors, with_labels=True, cmap=plt.cm.Oranges, node_size=500, font_weight='bold')
plt.show()

# %% [markdown]
# #### 2 - Centralidade de grau (degree centrality)

# %%
nx.degree_centrality(K)
# Out:
# {1: 0.48484848484848486,
#  2: 0.2727272727272727,
#  3: 0.30303030303030304,
#  4: 0.18181818181818182,
#  5: 0.09090909090909091,
#  6: 0.12121212121212122,
#  7: 0.12121212121212122,
#  8: 0.12121212121212122,
#  9: 0.15151515151515152,
#  10: 0.06060606060606061,
#  11: 0.09090909090909091,
#  12: 0.030303030303030304,
#  13: 0.06060606060606061,
#  14: 0.15151515151515152,
#  15: 0.06060606060606061,
#  16: 0.06060606060606061,
#  17: 0.06060606060606061,
#  18: 0.06060606060606061,
#  19: 0.06060606060606061,
#  20: 0.09090909090909091,
#  21: 0.06060606060606061,
#  22: 0.06060606060606061,
#  23: 0.06060606060606061,
#  24: 0.15151515151515152,
#  25: 0.09090909090909091,
#  26: 0.09090909090909091,
#  27: 0.06060606060606061,
#  28: 0.12121212121212122,
#  29: 0.09090909090909091,
#  30: 0.12121212121212122,
#  31: 0.12121212121212122,
#  32: 0.18181818181818182,
#  33: 0.36363636363636365,
#  34: 0.5151515151515151}

# %%
nx.degree_centrality(DG)
# Out:
# {'D': 1.0, 'A': 0.75, 'C': 0.75, 'E': 0.5, 'B': 1.0}

# %% [markdown]
# #### 3 - Centralidade do grau de entrada (in-degree) DG

# %%
nx.in_degree_centrality(DG)
# Out:
# {'D': 0.25, 'A': 0.5, 'C': 0.5, 'E': 0.25, 'B': 0.5}

# %% [markdown]
# #### 4 - Centralidade do grau de saída (out-degree) DG

# %%
nx.out_degree_centrality(DG)
# Out:
# {'D': 0.75, 'A': 0.25, 'C': 0.25, 'E': 0.25, 'B': 0.5}

# %% [markdown]
# #### 5 - Closeness Centrality

# %%
nx.closeness_centrality(K)
# Out:
# {1: 0.5689655172413793,
#  2: 0.4852941176470588,
#  3: 0.559322033898305,
#  4: 0.4647887323943662,
#  5: 0.3793103448275862,
#  6: 0.38372093023255816,
#  7: 0.38372093023255816,
#  8: 0.44,
#  9: 0.515625,
#  10: 0.4342105263157895,
#  11: 0.3793103448275862,
#  12: 0.36666666666666664,
#  13: 0.3707865168539326,
#  14: 0.515625,
#  15: 0.3707865168539326,
#  16: 0.3707865168539326,
#  17: 0.28448275862068967,
#  18: 0.375,
#  19: 0.3707865168539326,
#  20: 0.5,
#  21: 0.3707865168539326,
#  22: 0.375,
#  23: 0.3707865168539326,
#  24: 0.39285714285714285,
#  25: 0.375,
#  26: 0.375,
#  27: 0.3626373626373626,
#  28: 0.4583333333333333,
#  29: 0.4520547945205479,
#  30: 0.38372093023255816,
#  31: 0.4583333333333333,
#  32: 0.5409836065573771,
#  33: 0.515625,
#  34: 0.55}

# %%
(len(K.nodes())-1)/sum(nx.shortest_path_length(K,32).values())
# Out:
# 0.5409836065573771

# %% [markdown]
# #### 6 - Closeness Centrality DG

# %%
#nx.shortest_path(DG,'E')
nx.closeness_centrality(DG)
# Out:
# {'D': 0.5,
#  'A': 0.5714285714285714,
#  'C': 0.5714285714285714,
#  'E': 0.4444444444444444,
#  'B': 0.6666666666666666}

# %% [markdown]
# #### 7 - Betweenness Centrality

# %%
nx.betweenness_centrality(DG, endpoints=True)
# Out:
# {'D': 0.65,
#  'A': 0.5750000000000001,
#  'C': 0.42500000000000004,
#  'E': 0.4,
#  'B': 0.8}

# %% [markdown]
# #### 8 - Betweenness Centrality - Subset

# %%
#nx.betweenness_centrality(K)
nx.betweenness_centrality_subset(K, [34,33,21,30,16,27,15,23,10], [1,4,13,11,6,12,17,7])
# Out:
# {1: 25.869444444444447,
#  2: 0.0,
#  3: 9.698412698412698,
#  4: 1.1305555555555555,
#  5: 0.0,
#  6: 2.25,
#  7: 2.25,
#  8: 0.0,
#  9: 7.666269841269841,
#  10: 0.0,
#  11: 0.0,
#  12: 0.0,
#  13: 0.0,
#  14: 6.848412698412698,
#  15: 0.0,
#  16: 0.0,
#  17: 0.0,
#  18: 0.0,
#  19: 0.0,
#  20: 4.12063492063492,
#  21: 0.0,
#  22: 0.0,
#  23: 0.0,
#  24: 0.0,
#  25: 0.0,
#  26: 0.0,
#  27: 0.0,
#  28: 0.0,
#  29: 0.0,
#  30: 0.0,
#  31: 0.0,
#  32: 7.666269841269841,
#  33: 8.78968253968254,
#  34: 15.21031746031746}

# %% [markdown]
# #### 9 - Betweenness Centrality da Aresta

# %%
nx.edge_betweenness_centrality(DG)
# Out:
# {('D', 'A'): 0.17500000000000002,
#  ('D', 'C'): 0.07500000000000001,
#  ('D', 'E'): 0.2,
#  ('A', 'B'): 0.375,
#  ('C', 'B'): 0.225,
#  ('E', 'A'): 0.2,
#  ('B', 'C'): 0.15000000000000002,
#  ('B', 'D'): 0.45}

# %% [markdown]
# #### 10 - Betweenness Centrality da Aresta - Subset

# %%
nx.edge_betweenness_centrality_subset(K, [34,33,21,30,16,27,15,23,10], [1,4,13,11,6,12,17,7], normalized=True)
# Out:
# {(1, 2): 0.0,
#  (1, 3): 0.01211343123107829,
#  (1, 4): 0.0,
#  (1, 5): 0.0,
#  (1, 6): 0.012032085561497326,
#  (1, 7): 0.012032085561497326,
#  (1, 8): 0.0,
#  (1, 9): 0.01366536513595337,
#  (1, 11): 0.00802139037433155,
#  (1, 12): 0.00802139037433155,
#  (1, 13): 0.006006139829669241,
#  (1, 14): 0.007345160286336755,
#  (1, 18): 0.0,
#  (1, 20): 0.007345160286336755,
#  (1, 22): 0.0,
#  (1, 32): 0.01366536513595337,
#  (2, 3): 0.0,
#  (2, 4): 0.0,
#  (2, 8): 0.0,
#  (2, 14): 0.0,
#  (2, 18): 0.0,
#  (2, 20): 0.0,
#  (2, 22): 0.0,
#  (2, 31): 0.0,
#  (3, 4): 0.005174291938997821,
#  (3, 8): 0.0,
#  (3, 9): 0.0,
#  (3, 10): 0.0071301247771836,
#  (3, 14): 0.0,
#  (3, 28): 0.0,
#  (3, 29): 0.0,
#  (3, 33): 0.010157598392892509,
#  (4, 8): 0.0,
#  (4, 13): 0.0020152505446623093,
#  (4, 14): 0.004862348979996039,
#  (5, 7): 0.0,
#  (5, 11): 0.0,
#  (6, 7): 0.0,
#  (6, 11): 0.0,
#  (6, 17): 0.004010695187165775,
#  (7, 17): 0.004010695187165775,
#  (9, 31): 0.0,
#  (9, 33): 0.006320204849616614,
#  (9, 34): 0.007345160286336755,
#  (10, 34): 0.0,
#  (14, 34): 0.012207509266332794,
#  (15, 33): 0.0031335766629884275,
#  (15, 34): 0.003996548114195173,
#  (16, 33): 0.0031335766629884275,
#  (16, 34): 0.003996548114195173,
#  (19, 33): 0.0,
#  (19, 34): 0.0,
#  (20, 34): 0.007345160286336755,
#  (21, 33): 0.0031335766629884275,
#  (21, 34): 0.003996548114195173,
#  (23, 33): 0.0031335766629884275,
#  (23, 34): 0.003996548114195173,
#  (24, 26): 0.0,
#  (24, 28): 0.0,
#  (24, 30): 0.0,
#  (24, 33): 0.0,
#  (24, 34): 0.0,
#  (25, 26): 0.0,
#  (25, 28): 0.0,
#  (25, 32): 0.0,
#  (26, 32): 0.0,
#  (27, 30): 0.0,
#  (27, 34): 0.0071301247771836,
#  (28, 34): 0.0,
#  (29, 32): 0.0,
#  (29, 34): 0.0,
#  (30, 33): 0.0031335766629884275,
#  (30, 34): 0.003996548114195173,
#  (31, 33): 0.0,
#  (31, 34): 0.0,
#  (32, 33): 0.006320204849616614,
#  (32, 34): 0.007345160286336755,
#  (33, 34): 0.0}

# %% [markdown]
# #### 11 - Page Rank

# %%
nx.pagerank(DG)
# Out:
# {'D': 0.18095642215666966,
#  'A': 0.15035141786968964,
#  'C': 0.2322277097853423,
#  'E': 0.08127128762867264,
#  'B': 0.35519316255962585}

# %% [markdown]
# #### 12 - Page Rank Damping (alpha parameter)

# %%
DG.add_edges_from([('B','F'),('B','G'),('G','F'),('F','G')])


colors = []
for v in DG:
    colors.append(DG.degree(v));

nx.draw_kamada_kawai(DG, node_color=colors, with_labels=True, cmap=plt.cm.Oranges, node_size=500, font_weight='bold')
plt.show()

# %%
nx.pagerank(DG, alpha=0.65)
# Out:
# {'D': 0.08016914735549477,
#  'A': 0.11116065905985037,
#  'C': 0.09753919359758972,
#  'E': 0.06737004624209494,
#  'B': 0.18565536887379694,
#  'F': 0.22905279243558657,
#  'G': 0.22905279243558657}

# %% [markdown]
# #### 13 - Hubs e Autoridades (HITS)

# %%
nx.hits(DG)
# Out:
# ({'D': 0.2538714716933059,
#   'A': 1.816710417374254e-17,
#   'C': 1.816710417374254e-17,
#   'E': 0.06270107547398285,
#   'B': 0.4574605848884775,
#   'F': 0.11298343397211687,
#   'G': 0.11298343397211684},
#  {'D': 0.1588336036970477,
#   'A': 0.10991626417474243,
#   'C': 0.2469796037174671,
#   'E': 0.0881460000204194,
#   'B': 3.184730415796021e-17,
#   'F': 0.19806226419516168,
#   'G': 0.19806226419516174})

# %%
sorted(nx.hits(DG)[0].items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [('B', 0.4574605848884776),
#  ('D', 0.2538714716933058),
#  ('G', 0.11298343397211691),
#  ('F', 0.11298343397211688),
#  ('E', 0.0627010754739828),
#  ('A', 1.2905436768618614e-17),
#  ('C', 1.2905436768618614e-17)]
